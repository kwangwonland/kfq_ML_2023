# %% [markdown]
# <a href="https://colab.research.google.com/github/kwangwonland/kfq_ML_2023/blob/main/0717_%EB%94%A5%EB%9F%AC%EB%8B%9D_%EC%9D%BC%EB%B0%98%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras import models
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train,y_train),_=mnist.load_data()

# %%
x_train=x_train.reshape((-1,784))
x_train=x_train/255.0
x_train=x_train.astype('float32')

# %%
print(y_train)
print(ry_train)
# Out:
# [5 0 4 ... 5 6 8]
# [8 6 8 ... 4 4 5]

# %%
ry_train=y_train.copy()
np.random.shuffle(ry_train)
print(y_train)
print(ry_train)
# Out:
# [5 0 4 ... 5 6 8]
# [8 6 8 ... 4 4 5]

# %%
model=models.Sequential()
model.add(layers.Dense(512,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))

of=keras.optimizers.Adam(learning_rate=1.0)
model.compile(optimizer=of,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
hist1=model.fit(x_train,y_train,epochs=100,batch_size=128,validation_split=0.2)
# Out:
# Epoch 1/100
# 313/375 [========================>.....] - ETA: 0s - loss: 151.3661 - accuracy: 0.2283
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-7afc25c48a6e> in <cell line: 7>()
#       5 of=keras.optimizers.Adam(learning_rate=1.0)
#       6 model.compile(optimizer=of,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# ----> 7 hist1=model.fit(x_train,y_train,epochs=100,batch_size=128,validation_split=0.2)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
model=models.Sequential()
model.add(layers.Dense(512,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))

of=keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=of,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
hist1=model.fit(x_train,y_train,epochs=100,batch_size=128,validation_split=0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2934 - accuracy: 0.9172 - val_loss: 0.1693 - val_accuracy: 0.9505
# Epoch 2/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.1224 - accuracy: 0.9643 - val_loss: 0.1070 - val_accuracy: 0.9682
# Epoch 3/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0784 - accuracy: 0.9777 - val_loss: 0.0888 - val_accuracy: 0.9739
# Epoch 4/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0578 - accuracy: 0.9831 - val_loss: 0.0904 - val_accuracy: 0.9719
# Epoch 5/100
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0407 - accuracy: 0.9886 - val_loss: 0.0800 - val_accuracy: 0.9773
# Epoch 6/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0304 - accuracy: 0.9918 - val_loss: 0.0748 - val_accuracy: 0.9776
# Epoch 7/100
# ...

# %%
plt.plot(hist1.history['val_loss'],label='val_loss')
plt.plot(hist1.history['loss'],label='loss')
plt.legend()
plt.show()

# %%
from tensorflow.keras.datasets import imdb

# %%
(x_train,y_train),_=imdb.load_data(num_words=10000)
# Out:
# ...
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
def count_vectorize(sequences,dimension=10000):
    results=np.zeros((len(sequences),dimension))
    for i,sequence in enumerate(sequences):
        results[i,sequence]=1.
    return results
x_train=count_vectorize(x_train)
x_train.shape
# Out:
# (25000, 10000)

# %%
model=models.Sequential()
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))

model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

hist1=model.fit(x_train,y_train, epochs=20,batch_size=512,validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 87ms/step - loss: 0.5358 - accuracy: 0.7595 - val_loss: 0.3965 - val_accuracy: 0.8648
# Epoch 2/20
# 30/30 [==============================] - 3s 90ms/step - loss: 0.3263 - accuracy: 0.8907 - val_loss: 0.3102 - val_accuracy: 0.8865
# Epoch 3/20
# 30/30 [==============================] - 2s 55ms/step - loss: 0.2388 - accuracy: 0.9212 - val_loss: 0.2807 - val_accuracy: 0.8896
# Epoch 4/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.1944 - accuracy: 0.9335 - val_loss: 0.2775 - val_accuracy: 0.8893
# Epoch 5/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1637 - accuracy: 0.9457 - val_loss: 0.2853 - val_accuracy: 0.8857
# Epoch 6/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1407 - accuracy: 0.9551 - val_loss: 0.2849 - val_accuracy: 0.8897
# Epoch 7/20
# ...

# %%
model=models.Sequential()
model.add(layers.Dense(5,activation='relu'))
model.add(layers.Dense(4,activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))

model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

hist2=model.fit(x_train,y_train, epochs=20,batch_size=512,validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 73ms/step - loss: 0.6202 - accuracy: 0.6285 - val_loss: 0.5544 - val_accuracy: 0.7294
# Epoch 2/20
# 30/30 [==============================] - 4s 122ms/step - loss: 0.5186 - accuracy: 0.7987 - val_loss: 0.5057 - val_accuracy: 0.8151
# Epoch 3/20
# 30/30 [==============================] - 2s 78ms/step - loss: 0.4678 - accuracy: 0.8617 - val_loss: 0.4773 - val_accuracy: 0.8361
# Epoch 4/20
# 30/30 [==============================] - 2s 63ms/step - loss: 0.4312 - accuracy: 0.8942 - val_loss: 0.4807 - val_accuracy: 0.8062
# Epoch 5/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.4020 - accuracy: 0.9160 - val_loss: 0.4470 - val_accuracy: 0.8592
# Epoch 6/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.3775 - accuracy: 0.9319 - val_loss: 0.4563 - val_accuracy: 0.8402
# Epoch 7/20
# ...

# %%
model = models.Sequential()
model.add(layers.Dense(512,activation='relu'))
model.add(layers.Dense(512,activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
model.compile(loss = keras.losses.binary_crossentropy,
              metrics=['accuracy'])
hist3 = model.fit(x_train,y_train,
                 epochs=20,
                 batch_size=512,
                 validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 12s 385ms/step - loss: 0.5638 - accuracy: 0.7047 - val_loss: 0.4039 - val_accuracy: 0.8244
# Epoch 2/20
# 30/30 [==============================] - 11s 355ms/step - loss: 0.3328 - accuracy: 0.8612 - val_loss: 0.2996 - val_accuracy: 0.8745
# Epoch 3/20
# 30/30 [==============================] - 12s 421ms/step - loss: 0.2403 - accuracy: 0.9033 - val_loss: 0.2710 - val_accuracy: 0.8878
# Epoch 4/20
# 30/30 [==============================] - 12s 418ms/step - loss: 0.1930 - accuracy: 0.9272 - val_loss: 0.3031 - val_accuracy: 0.8759
# Epoch 5/20
# 30/30 [==============================] - 10s 336ms/step - loss: 0.1310 - accuracy: 0.9509 - val_loss: 0.3693 - val_accuracy: 0.8557
# Epoch 6/20
# 30/30 [==============================] - 10s 344ms/step - loss: 0.1092 - accuracy: 0.9597 - val_loss: 0.3012 - val_accuracy: 0.8850
# Epoch 7/20
# ...

# %%
plt.plot(hist1.history['val_loss'],label='middle')
plt.plot(hist2.history['val_loss'],label='simple')
plt.plot(hist3.history['val_loss'],label='complex')
plt.legend()
plt.show()

# %%
from keras import regularizers

# %%
model = models. Sequential()
model.add(layers.Dense(16,
                       kernel_regularizer=regularizers.l2(0.002),
                       activation='relu'))
model.add(layers.Dense(16,
                       kernel_regularizer=regularizers.l2(0.002),
                       activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
model.compile(loss=keras.losses.binary_crossentropy,metrics=['accuracy'])
hist= model.fit(x_train,y_train,epochs=20,
                batch_size=512,validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 65ms/step - loss: 0.6310 - accuracy: 0.7778 - val_loss: 0.4994 - val_accuracy: 0.8622
# Epoch 2/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.4297 - accuracy: 0.8879 - val_loss: 0.4113 - val_accuracy: 0.8764
# Epoch 3/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.3505 - accuracy: 0.9077 - val_loss: 0.3911 - val_accuracy: 0.8731
# Epoch 4/20
# 30/30 [==============================] - 2s 67ms/step - loss: 0.3082 - accuracy: 0.9193 - val_loss: 0.3587 - val_accuracy: 0.8888
# Epoch 5/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2832 - accuracy: 0.9289 - val_loss: 0.3537 - val_accuracy: 0.8870
# Epoch 6/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.2675 - accuracy: 0.9339 - val_loss: 0.3630 - val_accuracy: 0.8831
# Epoch 7/20
# ...

# %%
model = models. Sequential()
model.add(layers.Dense(16,
                       activation='relu'))
model.add(layers.Dense(16,
                       activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
model.compile(loss=keras.losses.binary_crossentropy,metrics=['accuracy'])
hist2= model.fit(x_train,y_train,epochs=20,
                batch_size=512,validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 79ms/step - loss: 0.5559 - accuracy: 0.7713 - val_loss: 0.4330 - val_accuracy: 0.8598
# Epoch 2/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.3509 - accuracy: 0.8907 - val_loss: 0.3301 - val_accuracy: 0.8792
# Epoch 3/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.2590 - accuracy: 0.9147 - val_loss: 0.2954 - val_accuracy: 0.8831
# Epoch 4/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.2059 - accuracy: 0.9318 - val_loss: 0.2760 - val_accuracy: 0.8901
# Epoch 5/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.1733 - accuracy: 0.9439 - val_loss: 0.2752 - val_accuracy: 0.8896
# Epoch 6/20
# 30/30 [==============================] - 2s 61ms/step - loss: 0.1497 - accuracy: 0.9520 - val_loss: 0.2816 - val_accuracy: 0.8885
# Epoch 7/20
# ...

# %%
plt.plot(hist.history['val_loss'],'-.',label ='val loss l2')
plt.plot(hist2.history['val_loss'],'-.',label ='val loss ori')
plt.plot(hist.history['loss'],label ='loss l2')
plt.plot(hist2.history['loss'],label ='loss ori')
plt.legend()
plt.show()

# %%
model = models.Sequential()
model.add(layers.Dense(16,
                       kernel_regularizer=regularizers.L1(l1=0.002),
                       activation='relu'))
model.add(layers.Dense(16,
                       kernel_regularizer=regularizers.L1(l1=0.002),
                       activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
model.compile(loss=keras.losses.binary_crossentropy,
               metrics=['accuracy'])
hist3 = model.fit(x_train, y_train, epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 4s 94ms/step - loss: 1.5709 - accuracy: 0.6884 - val_loss: 0.9163 - val_accuracy: 0.6942
# Epoch 2/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.8594 - accuracy: 0.8185 - val_loss: 0.8437 - val_accuracy: 0.7931
# Epoch 3/20
# 30/30 [==============================] - 2s 54ms/step - loss: 0.7948 - accuracy: 0.8373 - val_loss: 0.7838 - val_accuracy: 0.8319
# Epoch 4/20
# 30/30 [==============================] - 2s 51ms/step - loss: 0.7528 - accuracy: 0.8413 - val_loss: 0.7433 - val_accuracy: 0.8486
# Epoch 5/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.7206 - accuracy: 0.8482 - val_loss: 0.7302 - val_accuracy: 0.8348
# Epoch 6/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.6976 - accuracy: 0.8518 - val_loss: 0.7123 - val_accuracy: 0.8477
# Epoch 7/20
# ...

# %%
model = models. Sequential()
model.add(layers.Dense(16,
                       kernel_regularizer=regularizers.L1L2(l1=0.002,l2=0.002),
                       activation='relu'))
model.add(layers.Dense(16,
                       kernel_regularizer=regularizers.L1L2(l1=0.002,l2=0.002),
                       activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
model.compile(loss=keras.losses.binary_crossentropy,metrics=['accuracy'])
hist4= model.fit(x_train,y_train,epochs=20,
                batch_size=512,validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 71ms/step - loss: 1.5838 - accuracy: 0.7113 - val_loss: 0.9001 - val_accuracy: 0.7888
# Epoch 2/20
# 30/30 [==============================] - 1s 43ms/step - loss: 0.8593 - accuracy: 0.8055 - val_loss: 0.8312 - val_accuracy: 0.8270
# Epoch 3/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.8070 - accuracy: 0.8230 - val_loss: 0.7958 - val_accuracy: 0.8398
# Epoch 4/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.7737 - accuracy: 0.8349 - val_loss: 0.7745 - val_accuracy: 0.8340
# Epoch 5/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.7560 - accuracy: 0.8378 - val_loss: 0.7980 - val_accuracy: 0.8072
# Epoch 6/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.7390 - accuracy: 0.8389 - val_loss: 0.7473 - val_accuracy: 0.8395
# Epoch 7/20
# ...

# %%
plt.plot(hist.history['val_loss'],'-.',label ='val loss l2')
plt.plot(hist2.history['val_loss'],'-.',label ='val loss ori')
plt.plot(hist3.history['val_loss'],label ='val loss l1')
plt.plot(hist4.history['val_loss'],label ='val loss l1l2')
plt.legend()
plt.show()

# %%
model = models.Sequential()
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1,activation='sigmoid'))
model.compile(loss = keras.losses.binary_crossentropy,
              metrics=['accuracy'])
hist5 = model.fit(x_train,y_train,
                 epochs=20,
                 batch_size=512,
                 validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 4s 90ms/step - loss: 0.6594 - accuracy: 0.5978 - val_loss: 0.5898 - val_accuracy: 0.8291
# Epoch 2/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.5754 - accuracy: 0.7334 - val_loss: 0.5050 - val_accuracy: 0.8593
# Epoch 3/20
# 30/30 [==============================] - 2s 53ms/step - loss: 0.5006 - accuracy: 0.8009 - val_loss: 0.4160 - val_accuracy: 0.8699
# Epoch 4/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.4328 - accuracy: 0.8414 - val_loss: 0.3542 - val_accuracy: 0.8833
# Epoch 5/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.3793 - accuracy: 0.8695 - val_loss: 0.3192 - val_accuracy: 0.8851
# Epoch 6/20
# 30/30 [==============================] - 2s 58ms/step - loss: 0.3327 - accuracy: 0.8941 - val_loss: 0.3207 - val_accuracy: 0.8765
# Epoch 7/20
# ...

# %%
plt.plot(hist.history['val_loss'],'-.',label ='val loss l2')
plt.plot(hist2.history['val_loss'],'-.',label ='val loss ori')
plt.plot(hist3.history['val_loss'],label ='val loss l1')
plt.plot(hist4.history['val_loss'],label ='val loss l1l2')
plt.plot(hist5.history['val_loss'],label ='val loss dropout')
plt.legend()
plt.show()

# %% [markdown]
# # sequential 모델 사용

# %%
model=models.Sequential(
    [
        layers.Dense(64,activation='relu'),
        layers.Dense(10,activation='softmax')
    ]
)

# %%
model=models.Sequential()
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))

# %%
model.build(input_shape=(None,3))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_17 (Dense)            (None, 64)                256
#
#  dense_18 (Dense)            (None, 10)                650
#
# ...
# Total params: 906
# Trainable params: 906
# Non-trainable params: 0
# _________________________________________________________________

# %%
model=models.Sequential(name='jinmoon_s_model')
model.add(layers.Dense(64,activation='relu',name='abcd'))
model.add(layers.Dense(10,activation='softmax',name='efgh'))
model.build(input_shape=(None,10))

# %%
model.summary()
# Out:
# Model: "jinmoon_s_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  abcd (Dense)                (None, 64)                704
#
#  efgh (Dense)                (None, 10)                650
#
# ...
# Total params: 1,354
# Trainable params: 1,354
# Non-trainable params: 0
# _________________________________________________________________
