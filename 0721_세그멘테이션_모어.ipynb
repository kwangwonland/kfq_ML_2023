# %% [markdown]
# <a href="https://colab.research.google.com/github/kwangwonland/kfq_ML_2023/blob/main/0721_%EC%84%B8%EA%B7%B8%EB%A9%98%ED%85%8C%EC%9D%B4%EC%85%98_%EB%AA%A8%EC%96%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from keras.utils import load_img,img_to_array
from keras import layers
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path="C:/Users/USER/Downloads/dog.PNG"

# %%
img_size=(200,200)
def path_to_input(path):
    return img_to_array(load_img(path,target_size=img_size))

# %%
model=keras.models.load_model('/content/drive/MyDrive/python_basic/data/oxford_segmentation.keras')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      36928
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 256)       590080
#
#  conv2d_transpose (Conv2DTra  (None, 25, 25, 256)      590080
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 50, 50, 256)      590080
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 50, 50, 128)      295040
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 100, 100, 128)    147584
#  ranspose)
#
# ...

# %%
di2=path_to_input('/content/drive/MyDrive/python_basic/data/dog.PNG')
di2.shape
# Out:
# (200, 200, 3)

# %%
plt.imshow(di2.astype('uint8'))
plt.show()

# %%
di2=di2.reshape(1,200,200,3)
mask=model.predict(di2)[0]
plt.imshow(mask)
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
dest = np.zeros((200,200,3),dtype='uint8')
for ch in range(3):
  for r in range(200):
    for c in range(200):
      if rm[r][c][ch] == 0:
        dest[r][c][ch]=di2[r][c][ch]
      else:
        dest[r][c][ch]=di2[r][c][ch]
plt.imshow(dest)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-d65a9ea93e3d> in <cell line: 2>()
#       4     for c in range(200):
#       5       if rm[r][c][ch] == 0:
# ----> 6         dest[r][c][ch]=di2[r][c][ch]
#       7       else:
#       8         dest[r][c][ch]=di2[r][c][ch]
#
# ValueError: setting an array element with a sequence.
